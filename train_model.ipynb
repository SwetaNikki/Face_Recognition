# %%
#importing library
import numpy as np
import cv2
import os
#%run faceRecognition.ipynb

# %%
#running other py file
# %run faceRecognition.ipynb
#import faceRecognition as fr

# %%
#Training will begin from here

#Give path to the train-images folder which has labeled folder
faces,faceID=labels_for_training_data('trainset') 
face_recognizer=train_classifier(faces,faceID)
#saving the trained model. Just give path to where you want to save
face_recognizer.save('trainingData.yml') 



print("------------------------------TRAINING COMPLETED---------------------------------")
# Out:
# img_path:  trainset\0001\0001_0000255\0000001.jpg
# id:  0001_0000255
# img_path:  trainset\0001\0001_0000255\0000005.jpg
# id:  0001_0000255
# img_path:  trainset\0001\0001_0000255\0001_0000255_script.jpg
# id:  0001_0000255
# img_path:  trainset\0001\0001_0000255\Thumbs.db
# id:  0001_0000255
# Not Loaded Properly
# img_path:  trainset\0001\0001_0000262\0000011.jpg
# id:  0001_0000262
# img_path:  trainset\0001\0001_0000262\0001_0000262_script.jpg
# id:  0001_0000262
# img_path:  trainset\0001\0001_0000262\0001_0000262_script_2.jpg
# id:  0001_0000262
# img_path:  trainset\0001\0001_0000262\Thumbs.db
# id:  0001_0000262
# Not Loaded Properly
# img_path:  trainset\0001\0001_0000264\0000004.jpg
# id:  0001_0000264
# img_path:  trainset\0001\0001_0000264\0000006.jpg
# id:  0001_0000264
# img_path:  trainset\0001\0001_0000264\0001_0000264_script.jpg
# id:  0001_0000264
# img_path:  trainset\0001\0001_0000264\Thumbs.db
# id:  0001_0000264
# Not Loaded Properly
# ...
